# %%
#tkinter
from tkinter import *   #tkinter은 패키지
root=Tk()      #TK클래스의 객체 root 생성
root.title('my first tkinter')  #제목 생성
root.geometry('400x200+0+300')  #크기와 위치 설정
root.mainloop()   #결과를 화면에 보여주는 메서드

# %%
#텍스트 레이블
from tkinter import *
root=Tk()      #객체 root 생성
root.title('my first tkinter')  #제목 생성
root.geometry('400x200+0+300')  #크기와 위치 설정
label1=Label(root,text='안녕하세요!',font=('Malgun Gothic',20),fg='blue',bg='gray',width=20,height=5,anchor='se')
label1.pack()
root.mainloop()   #결과를 화면에 보여주는 메서드

# %%
#이미지 레이블
from tkinter import *
root=Tk()
root.title('my first tkinter')
root.geometry('800x400')
letgetit=PhotoImage(file='lets get it.png')  #객체 생성
letgetit=letgetit.subsample(2,2) #크기 설정
img_label=Label(root,image=letgetit)  #레이블 객체 생성
img_label.pack()

root.mainloop()

# %%
#절대위치로 배치
from tkinter import *
root=Tk()
root.geometry('400x200')

label1=Label(root,text='절대위치 x = 200, y = 100')
label1.place(x=200,y=100)  #절대위치로 배치

root.mainloop()

# %%
#상대위치로 배치
from tkinter import *
root=Tk()
root.geometry('400x200')

label1=Label(root,text='안녕하세요')
label1.pack(side='left')  #상대위치로 배치(위치 설정)

label2=Label(root,text='나히오')
label2.pack(side='right')  #상대위치로 배치

label3=Label(root,text='봉쥬르')
label3.pack(side='top')  #상대위치로 배치

label4=Label(root,text='hello')
label4.pack(side='bottom')  #상대위치로 배치
root.mainloop()

# %%
#상대위치로 배치
from tkinter import *
root=Tk()
root.geometry('400x200')

label1=Label(root,text='안녕하세요')
label1.grid(row=0,column=0)  #상대위치로 배치(위치 설정)

label2=Label(root,text='나히오')
label2.grid(row=0,column=1)

label3=Label(root,text='봉쥬르')
label3.grid(row=1,column=0)

label4=Label(root,text='hello')
label4.grid(row=1,column=1)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.geometry('400x200')

label1=Label(root,text='안녕하세요',width=20,height=5,relief='raised')
label1.grid(row=0,column=0)  #상대위치로 배치(위치 설정)

label2=Label(root,text='나히오',width=10,height=5,relief='raised')
label2.grid(row=0,column=1)

label3=Label(root,text='봉쥬르',width=10,height=5,relief='raised')
label3.grid(row=1,column=0,columnspan=2)

label4=Label(root,text='hello',width=20,height=5,relief='raised')
label4.grid(row=1,column=1,rowspan=2)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.title('my first tkinter')
root.geometry('700x450')
label_txt=Label(root,text='파이썬 프로그래밍',font=('Malgun Gothic',30))
label_txt.grid(row=0,column=0)
letgetit=PhotoImage(file='lets get it.png')  #객체 생성
img_label=Label(root,image=letgetit)  #레이블 객체 생성
img_label.grid(row=1,column=0)

root.mainloop()

# %%
#버튼 눌렀을 때
from tkinter import *
def sayhello():
    txt.set('hello'*3)

root=Tk()
root.title('Button')
root.geometry('400x200')

lbl1=Label(root,text='안녕하세요',width=40)
lbl1.grid(row=0,column=0)
btn1=Button(root,text='확인',width=10,command=sayhello)
btn1.grid(row=0,column=1)
txt=StringVar()  #동적변수 정의
lbl2=Label(root,textvariable=txt,width=40,height=3)
lbl2.grid(row=1,column=0,columnspan=2)

root.mainloop()

# %%
#구구단 문제
from tkinter import *
import random

num1,num2=0,0 #전역변수
def make_question():
    global num1,num2
    num1,num2=random.randint(2,9),random.randint(1,9)
    question.set(str(num1)+'x'+str(num2)+'?')

def check_answer():
    answer.set(num1*num2)

root=Tk()
root.title('구구단')

question=StringVar()  #무작위로 생성된 구구단 문제를 저장하는 동적변수
q_lbl=Label(root,textvariable=question,width=30) 
q_lbl.grid(row=0,column=0)

q_btn=Button(root,text='새로운 문제',width=10,command=make_question)
q_btn.grid(row=0,column=1)

a_btn=Button(root,text='정답 확인',width=10,command=check_answer)
a_btn.grid(row=1,column=1)

answer=StringVar()  #구구단 문제의 정답을 저장하는 동적변수
a_lbl=Label(root,textvariable=answer,width=30)
a_lbl.grid(row=1,column=0)

root.mainloop()

# %%
#엔트리
from tkinter import *
root=Tk()
root.title('entry')
root.geometry('400x200')
ent=Entry(root,width=25)
ent.grid(row=0,column=0)
root.mainloop()

# %%
from tkinter import *
root=Tk()
root.title('entry')
root.geometry('400x200')

lbl=Label(root,text='이름 : ',width=10)
lbl.grid(row=0,column=0)

ent=Entry(root,width=25)
ent.grid(row=0,column=1)

root.mainloop()

# %%
from tkinter import *
def entry_value():
    print(ent.get())  #함수 실행시 get()으로 ent의 값을 읽어 들여 출력함

root=Tk()
root.title('entry')
root.geometry('400x200')

lbl=Label(root,text='이름 : ',width=10)
lbl.grid(row=0,column=0)

ent=Entry(root,width=25)
ent.grid(row=0,column=1)

btn=Button(root,text='확인',width=0,command=entry_value)
btn.grid(row=0,column=2)

root.mainloop()
# Out:
# 김서하
# 김서하

# %%
from tkinter import *

root=Tk()
root.title('Login')
root.geometry('400x200')

id_lbl=Label(root,text='아이디 ',width=10)
id_lbl.grid(row=0,column=0)
id_ent=Entry(root,width=20)
id_ent.grid(row=0,column=1)

pw_lbl=Label(root,text='비밀번호 ',width=10)
pw_lbl.grid(row=1,column=0)
pw_ent=Entry(root,width=20)
pw_ent.grid(row=1,column=1)

btn=Button(root,text='로그인',width=5, height=3)
btn.grid(row=0,column=2,rowspan=2)

root.mainloop()

# %%
from tkinter import *

def login():
    if id_ent.get()=='Lian'and pw_ent.get()=='1234':
        result.set('로그인 성공')
    else:
        result.set('로그인 실패. \n 아이디와 비밀번호를 다시 확인하세요!')

root=Tk()
root.title('Login')
root.geometry('400x200')

id_lbl=Label(root,text='아이디 ',width=10)
id_lbl.grid(row=0,column=0)
id_ent=Entry(root,width=20)
id_ent.grid(row=0,column=1)

pw_lbl=Label(root,text='비밀번호 ',width=10)
pw_lbl.grid(row=1,column=0)
pw_ent=Entry(root,width=20)
pw_ent.grid(row=1,column=1)

btn=Button(root,text='로그인',width=5, height=3, command=login)
btn.grid(row=0,column=2,rowspan=2)

result=StringVar() #로그인 성공 여부를 저장하는 동적 변수

result_lbl=Label(root,textvariable=result,width=30)
result_lbl.grid(row=2,column=0,columnspan=3)

root.mainloop()

# %%
#콤보박스
from tkinter import *
from tkinter.ttk import *

root=Tk()
root.title('ComboBox')
root.geometry('400x200')

#콤보박스에 나타낼 리스트
characters=['죠르디','프로도','라이언','무지','어피지']

#콤보박스 객체 생성, characters 리스트 연결
combo=Combobox(root,values=characters)
combo.pack()

root.mainloop()

# %%
from tkinter import *
from tkinter.ttk import *

root=Tk()
root.title('ComboBox')
root.geometry('400x200')

def select():
    print('선택된 캐릭터는 ',combo.get())
    
lbl=Label(root,text='캐릭터 이름',width=10,anchor='center')
lbl.grid(row=0,column=0)

#콤보박스에 나타낼 리스트
characters=['죠르디','프로도','라이언','무지','어피지']

#콤보박스 객체 생성, characters 리스트 연결
combo=Combobox(root,values=characters,width=30)
combo.grid(row=0,column=1)

btn=Button(root,text='선택',command=select,width=10)
btn.grid(row=0,column=2)

root.mainloop()
# Out:
# 선택된 캐릭터는  어피지

# %%
from tkinter import *
from tkinter.ttk import *
import random

num1,num2=0,0

def make_question():
    global num1,num2
    #문제 만들기
    num1,num2=random.randint(2,9),random.randint(1,9)
    question.set(str(num1)+'x'+str(num2)+'?')
    #선택지 초기화하고 새로 만들기
    selection=[]
    for i in range(4):
        selection.append(random.randint(2,81))
    #무작위 위치에 정답 끼워 넣기
    idx=random.randint(0,4)
    selection.insert(idx,num1*num2)
    
    #콤보박스에 변경된 리시트 연결하기
    a_combo['values']=selection
    
root=Tk()
root.title('구구단')
root.geometry('400x200')

question=StringVar()
q_lbl=Label(root,textvariable=question,width=30,anchor='center')
q_lbl.grid(row=0,column=0)
q_btn=Button(root,text='새로운 문제',width=10,command=make_question)
q_btn.grid(row=0,column=1)

selection=[]
a_combo=Combobox(root,values=selection,width=30)
a_combo.grid(row=1,column=0)
a_btn=Button(root,text='정답 확인',width=10)
a_btn.grid(row=1,column=1)

root.mainloop()

# %%
#메시지박스
from tkinter import *
from tkinter.messagebox import *

root=Tk()
root.geometry('400x200')
showinfo(title='메시지박스',message='회원가입이 완료되었습니다!')  #i 이미지
root.mainloop()

# %%
#메시지박스
from tkinter import *
from tkinter.messagebox import *

root=Tk()
root.geometry('400x200')
showerror(title='메시지박스',message='이미 가입된 회원입니다')   #x 이미지
root.mainloop()

# %%
#구구단에 매시지박스 추가
from tkinter import *
from tkinter.ttk import *
from tkinter.messagebox import *
import random

num1,num2=0,0

def make_question():
    global num1,num2
    #문제 만들기
    num1,num2=random.randint(2,9),random.randint(1,9)
    question.set(str(num1)+'x'+str(num2)+'?')
    #선택지 초기화하고 새로 만들기
    selection=[]
    for i in range(4):
        selection.append(random.randint(2,81))
    #무작위 위치에 정답 끼워 넣기
    idx=random.randint(0,4)
    selection.insert(idx,num1*num2)
    
    #콤보박스에 변경된 리시트 연결하기
    a_combo['values']=selection
    
def check_answer():
    if int(a_combo.get())==num1*num2:
        showinfo(title='정답 확인!',message='정답입니다!')
    else:
        showerror(title='정답 확인!',message='다시 한번 풀어 보세요!')
root=Tk()
root.title('구구단')
root.geometry('400x200')

question=StringVar()
q_lbl=Label(root,textvariable=question,width=30,anchor='center')
q_lbl.grid(row=0,column=0)
q_btn=Button(root,text='새로운 문제',width=10,command=make_question)
q_btn.grid(row=0,column=1)

selection=[]
a_combo=Combobox(root,values=selection,width=30)
a_combo.grid(row=1,column=0)
a_btn=Button(root,text='정답 확인',width=10,command=check_answer)
a_btn.grid(row=1,column=1)

root.mainloop()

# %%
#프레임
from tkinter import *

root=Tk()
root.title('frame')
root.geometry('400x200')

frame_a=Frame(root,relief='groove',borderwidth=2)
frame_a.grid(row=0,column=0)
frame_b=Frame(root,relief='groove',borderwidth=2)
frame_b.grid(row=1,column=0)

id_lbl=Label(frame_a,text='아이디',width=10,height=2)
id_lbl.grid(row=0,column=0)
id_ent=Entry(frame_a,width=20)
id_ent.grid(row=0,column=1)

pw_lbl=Label(frame_b,text='비밀번호',width=10,height=2)
pw_lbl.grid(row=0,column=0)
pw_ent=Entry(frame_b,width=20)
pw_ent.grid(row=0,column=1)

root.mainloop()

# %%
#웹 페이지 화면 만들기
from tkinter import *

root=Tk()
root.title('frame')
root.geometry('400x200')

#-프레임 생성-
frame_logo=Frame(root)
frame_logo.grid(row=0,column=0)
frame_search=Frame(root)
frame_search.grid(row=1,column=0)
frame_weather=Frame(root)
frame_weather.grid(row=2,column=0)

#-로고 프레임-
logo=PhotoImage(file='lets get it.png')
logo=logo.subsample(6,6)
logo_label=Label(frame_logo,image=logo)
logo_label.grid(row=0,column=0)
site_title=Label(frame_logo,text='렛츠기릿',font=('Malgun Gothic',20))
site_title.grid(row=0,column=1)

#-검색 프레임-
search_lbl=Label(frame_search,text='검색어 입력',width=10)
search_lbl.grid(row=0,column=0)
search_ent=Entry(frame_search,width=25)
search_ent.grid(row=0,column=1)
search_btn=Button(frame_search,text='검색',width=8)
search_btn.grid(row=0,column=2)

#-날씨 프레임
weather_title=Label(frame_weather,text='오늘의 날씨',font=('Malgun Gothic',10),width=10)
weather_title.grid(row=0,column=0,rowspan=2)
weather_temperature=Label(frame_weather,text='28도',font=('Malgun Gothic',14),width=5)
weather_temperature.grid(row=0,column=1,rowspan=2)
weather_explain=Label(frame_weather,text='흐림,어제보다 0도 높아요. 체감온도 30.4',width=35)
weather_explain.grid(row=0,column=2)
weather_info=Label(frame_weather,text='미세먼지 좋음 / 초미세먼지 좋음',width=35)
weather_info.grid(row=1,column=2)

root.mainloop()

# %%
#핫플레이스 프로젝트 화면
from tkinter import *
import csv
import matplotlib.pyplot as plt
import datetime

def file_open():
    # 인구 데이터 파일 읽기
    f = open('LOCAL_PEOPLE_DONG_201912.csv', encoding='utf8')
    data = csv.reader(f)
    next(data)
    data = list(data)

    # 행정동 코드 파일 읽기
    f2 = open('dong_code.csv')
    code_data = csv.reader(f2)
    next(code_data)
    next(code_data)
    code_data = list(code_data)

    # 인구 데이터 자료형 변환 (문자열->정수, 실수)
    for row in data:
        for i in range(1, 32):
            if i <= 2:
                row[i] = int(row[i])
            else:
                row[i] = float(row[i])

    # 행정동 코드 데이터 자료형 변환 (문자열->정수)
    for row in code_data:
        row[1] = int(row[1])
    return data, code_data

# 핫플레이스가 있는 행정동명의 행정동코드를 찾는 함수
def dong_search1():
    global dong_name1, dong_code1
    dong_name1 = dong_ent1.get()
    
    for row in code_data:
        if row[-1] == dong_name1:
            dong_code1 = row[1]
    info.set(dong_name1 + '-' + str(dong_code1) +'을 분석합니다.')
    
# 비교할 행정동명의 행정동코드를 찾는 함수
def dong_search2():
    global dong_name2, dong_code2
    dong_name2 = dong_ent2.get()
    
    for row in code_data:
        if row[-1] == dong_name2:
            dong_code2 = row[1]
    info.set(dong_name1 + '과 ' + dong_name2 +'을 분석합니다.')
    
# 그래프 그리는 함수
def graph_plot(pop_list, label_list, graph_title):
    plt.figure(figsize=(10, 5)) #그래프 크기
    plt.rc('font', family='Malgun Gothic')
    plt.title(graph_title)
    for i in range(len(pop_list)):
        plt.plot(range(24), pop_list[i], label=label_list[i])
    plt.legend()
    plt.xlabel('시간대')
    plt.ylabel('평균인구수')
    plt.xticks(range(24), range(24))
    plt.savefig('graph.png') # 그래프를 이미지로 저장
    plt.show()
    
    # 그래프 이미지를 객체로 만들고 레이블에 표시
    graph_img = PhotoImage(file='graph.png')
    graph_lbl.configure(image=graph_img)
    graph_lbl.image = graph_img
    
# 하위목표1
def analysis1(graph_yn='y'):
    pop = [0 for i in range(24)]
    for row in data:
        if row[2] == dong_code1:
            time, p = row[1], row[3]
            pop[time] += p
    pop = [p/31 for p in pop]
    if graph_yn == 'n':
        return pop
    pop = [pop]
    labels = ['평균인구']
    title = dong_name1 + ' 시간대별 평균인구'
    graph_plot(pop_list=pop, label_list=labels, graph_title = title)
    
# 하위목표2
def analysis2():
    weekday = [0 for i in range(24)]
    weekend = [0 for i in range(24)]
    
    for row in data:
        if row[2] == dong_code1:
            time, p = row[1], row[3]
            year, mon, day = int(row[0][:4]), int(row[0][4:6]),int(row[0][6:])
            num = datetime.date(year, mon, day).weekday()
            if num < 5:
                weekday[time] += p
            else:
                weekend[time] += p
                    
    weekday_cnt, weekend_cnt = 0, 0
    for i in range(1, 32):
        if datetime.date(2022, 5, i).weekday() < 5:
            weekday_cnt += 1
        else:
            weekend_cnt += 1
            
    weekday = [w/weekday_cnt for w in weekday]
    weekend = [w/weekend_cnt for w in weekend]
    
    data_set = [weekday, weekend]
    labels = ['주중', '주말']
    title = dong_name1 + ' 주중/주말 시간대별 평균인구'
    graph_plot(pop_list=data_set, label_list=labels, graph_title=title)
    
# 하위목표3
def analysis3():
    male = [0 for i in range(24)]
    female = [0 for i in range(24)]

    for row in data:
        if row[2] == dong_code1:
            time = row[1]
            male[time] += sum(row[4:18])
            female[time] += sum(row[18:32])
    male = [m/31 for m in male]
    female = [f/31 for f in female]

    # 평균 인구 리스트로 꺾은 선 그래프 작성
    data_set = [male, female]
    labels = ['남성', '여성']
    title = dong_name1 + ' 남여 시간대별 평균 인구'
    graph_plot(pop_list = data_set, label_list=labels, graph_title=title)
    
# 하위목표4
def analysis4():
    pop1 = analysis1(graph_yn = 'n')
    pop2 = [0 for i in range(24)]
    
    for row in data:
        if row[2] == dong_code2:
            time, p = row[1], row[3]
            pop2[time] += p
    pop2 = [p/31 for p in pop2]

    # 평균 인구 리스트로 꺾은 선 그래프 작성
    data_set = [pop1, pop2]
    labels = [dong_name1, dong_name2]
    title = dong_name1 + '과 ' + dong_name2 + ' 시간대별 평균 인구'
    graph_plot(pop_list = data_set, label_list=labels, graph_title=title)
        
        
# 전역변수
data, code_data = file_open()
dong_name1, dong_code1 = '', ''
dong_name2, dong_code2 = '', ''

# GUI
root = Tk()
root.geometry('800x500')
root.title('핫플레이스는 언제 가야 덜 붐빌까')

Menu = Frame(root)
Menu.grid(row=0, column=0)
Graph = Frame(root)
Graph.grid(row=1, column=0)

dong_ent1 = Entry(Menu, width=20)
dong_ent1.grid(row=0, column=0)

dong_btn1 = Button(Menu, text='핫플레이스 행정동 설정', width=20, command=dong_search1)
dong_btn1.grid(row=0, column=1)

dong_ent2 = Entry(Menu, width=20)
dong_ent2.grid(row=0, column=2)

dong_btn2 = Button(Menu, text='비교할 행정동 설정', width=20, command=dong_search2)
dong_btn2.grid(row=0, column=3)

info = StringVar()
dong_lbl = Label(Menu, textvariable=info, font=('Malgun Gothic', 12))
dong_lbl.grid(row=1, columnspan=4)

# 그래프 프레임
btn1 = Button(Graph, text='1. 시간대별 그래프', width=20, command=analysis1)
btn1.grid(row=0, column=0)
btn2 = Button(Graph, text='2. 주중/주말 그래프', width=20, command=analysis2)
btn2.grid(row=0, column=1)
btn3 = Button(Graph, text='3. 남녀 그래프', width=20, command=analysis3)
btn3.grid(row=0, column=2)
btn4 = Button(Graph, text='4. 지역별 그래프', width=20, command=analysis4)
btn4.grid(row=0, column=3)

graph_lbl = Label(Graph)
graph_lbl.grid(row=1, column=0, columnspan=5)

root.mainloop()

# %%
#1
from tkinter import *

sayhello=['안녕하세요','hello','니하오','봉쥬르']
idx=0

def plus():
    global idx
    idx=(idx+1)%4
    hello_txt.set(sayhello[idx])

def minus():
    global idx
    idx=(idx-1)%4
    hello_txt.set(sayhello[idx])

root=Tk()
root.geometry('250x100')

btn_minus=Button(root,text='<--',command=minus,width=5)
btn_minus.grid(row=0,column=0)

hello_txt=StringVar()
hello_lbl=Label(root,textvariable=hello_txt,width=20)
hello_lbl.grid(row=0,column=1)

btn_plus=Button(root,text='-->',command=plus,width=5)
btn_plus.grid(row=0,column=2)

root.mainloop()

# %%
#2
from tkinter import *
from tkinter.ttk import *

def summit():
    answer=0
    if combo1.get() == 'O':
        answer+=1
    if combo2.get() == 'X':
        answer+=1
    if combo3.get() == 'O':
        answer+=1
        
    result.set(str(answer) + '문제 맞혔습니다.')

root=Tk()
root.title('수도 맞히기 퀴즈')
root.geometry('400x200')

result=StringVar()
ox=['O','X']

# 1번 문제
lbl1 = Label(root, text='1번. 핀란드의 수도는 헬싱키다.', width=40)
lbl1.grid(row=0, column=0)
combo1=Combobox(root, values=ox, width=3)
combo1.grid(row=0, column=1)

# 2번 문제
lbl2=Label(root, text='2번. 몰디브의 수도는 몰디브이다.', width=40)
lbl2.grid(row=1, column=0)
combo2=Combobox(root, values=ox, width=3)
combo2.grid(row=1, column=1)

# 3번 문제
lbl3=Label(root, text='3번. 오스트레일리아의 수도는 캔버라다.', width=40)
lbl3.grid(row=2, column=0)
combo3=Combobox(root, values=ox, width=3)
combo3.grid(row=2, column=1)

btn=Button(root, text='제출', width=5, command=summit)
btn.grid(row=3, column=0, columnspan=2)

lbl_result=Label(root, textvariable=result, width=35, anchor='center')
lbl_result.grid(row=4, column=0, columnspan=3)

root.mainloop()
